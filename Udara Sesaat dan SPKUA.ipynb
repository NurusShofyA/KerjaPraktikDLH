# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Upload Dataset dan Preprocessing

# %%
Sementara = pd.read_csv("C:\\Users\\Dell\\Downloads\\Udara Sesaat.csv")
Sementara.head()
# Out:
#    NO                             LOKASI PERUNTUKAN KAWASAN  PM2.5    PM10  \
# 0   1     Kantor Kelurahan Bulak Banteng          Pemukiman   9.41   57.55
# 1   2  Kantor Kelurahan Penjaringan Sari          Pemukiman  48.32  154.58
# 2   3         Kantor Kecamatan Mulyorejo          Pemukiman  11.37   41.86
# 3   4       Kantor Kelurahan Pucang Sewu          Pemukiman  32.95  169.23
# 4   5         Kantor Kelurahan Wonokromo          Pemukiman  44.74  205.53
#
#    Tahun
# 0   2023
# 1   2023
# 2   2023
# 3   2023
# 4   2023

# %%
Sementara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NO                  213 non-null    int64
#  1   LOKASI              213 non-null    object
#  2   PERUNTUKAN KAWASAN  213 non-null    object
#  3   PM2.5               212 non-null    float64
#  4   PM10                212 non-null    float64
#  5   Tahun               213 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 10.1+ KB

# %%
Sementara = Sementara.dropna()
Sementara.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 212 entries, 0 to 212
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   NO                  212 non-null    int64
#  1   LOKASI              212 non-null    object
#  2   PERUNTUKAN KAWASAN  212 non-null    object
#  3   PM2.5               212 non-null    float64
#  4   PM10                212 non-null    float64
#  5   Tahun               212 non-null    int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 11.6+ KB

# %%
Sementara.drop(columns=['NO'],inplace=True)
Sementara.head()
# Out:
#                               LOKASI PERUNTUKAN KAWASAN  PM2.5    PM10  Tahun
# 0     Kantor Kelurahan Bulak Banteng          Pemukiman   9.41   57.55   2023
# 1  Kantor Kelurahan Penjaringan Sari          Pemukiman  48.32  154.58   2023
# 2         Kantor Kecamatan Mulyorejo          Pemukiman  11.37   41.86   2023
# 3       Kantor Kelurahan Pucang Sewu          Pemukiman  32.95  169.23   2023
# 4         Kantor Kelurahan Wonokromo          Pemukiman  44.74  205.53   2023

# %%
Tandes = pd.read_csv("C:\\Users\\Dell\\Downloads\\Data Tandes - Sheet1.csv")
Tandes.head()
# Out:
#    Lokasi     Tanggal            X              Y  PM10  PM2.5  SO2    CO  \
# 0  Tandes  01/01/2020  725,891,944  1,126,779,639    19     20   22  3125
# 1  Tandes  02/01/2020  725,891,944  1,126,779,639    12     13   22  3332
# 2  Tandes  03/01/2020  725,891,944  1,126,779,639    21     22   24  2922
# 3  Tandes  04/01/2020  725,891,944  1,126,779,639    13     14   28  2507
# 4  Tandes  05/01/2020  725,891,944  1,126,779,639    12     12   37  1863
#
#      O3  NO2  HC
# 0  84.0    4   0
# 1  88.0    5   0
# 2  88.0    4   0
# 3  77.0    4   0
# 4  65.0    4   0

# %%
Tandes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1808 entries, 0 to 1807
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Lokasi   1808 non-null   object
#  1   Tanggal  1808 non-null   object
#  2   X        1808 non-null   object
#  3   Y        1808 non-null   object
#  4   PM10     1808 non-null   int64
#  5   PM2.5    1808 non-null   int64
#  6   SO2      1808 non-null   int64
#  7   CO       1808 non-null   int64
#  8   O3       1806 non-null   float64
#  9   NO2      1808 non-null   int64
#  10  HC       1808 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 155.5+ KB

# %%
Tandes=Tandes.dropna()
Tandes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1806 entries, 0 to 1807
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Lokasi   1806 non-null   object
#  1   Tanggal  1806 non-null   object
#  2   X        1806 non-null   object
#  3   Y        1806 non-null   object
#  4   PM10     1806 non-null   int64
#  5   PM2.5    1806 non-null   int64
#  6   SO2      1806 non-null   int64
#  7   CO       1806 non-null   int64
#  8   O3       1806 non-null   float64
#  9   NO2      1806 non-null   int64
#  10  HC       1806 non-null   int64
# dtypes: float64(1), int64(6), object(4)
# memory usage: 169.3+ KB

# %%
Tandes.drop(columns=['Lokasi','X','Y','SO2','CO','O3','NO2','HC'],inplace=True)
Tandes.head()
# Out:
#       Tanggal  PM10  PM2.5
# 0  01/01/2020    19     20
# 1  02/01/2020    12     13
# 2  03/01/2020    21     22
# 3  04/01/2020    13     14
# 4  05/01/2020    12     12

# %%
Tandes['Tahun']=Tandes['Tanggal'].str[-2:]
Tandes.head()
# Out:
#       Tanggal  PM10  PM2.5 Tahun
# 0  01/01/2020    19     20    20
# 1  02/01/2020    12     13    20
# 2  03/01/2020    21     22    20
# 3  04/01/2020    13     14    20
# 4  05/01/2020    12     12    20

# %%
Tandes['Tahun'].unique()
# Out:
# array(['20', '21', '22', '23', '24'], dtype=object)

# %%
Gabungan = pd.read_csv("C:\\Users\\Dell\\Downloads\\Data Wonorejo dan Kebonsari.csv")
Gabungan.head()
# Out:
#      Lokasi     Tanggal        X              Y   PM10  PM2.5   SO2    CO  \
# 0  Wonorejo  01/01/2019  731,185  1,127,891,639  11.98      0  9.01  0.57
# 1  Wonorejo  02/01/2019  731,185  1,127,891,639  12.04      0  7.19  0.61
# 2  Wonorejo  03/01/2019  731,185  1,127,891,639   8.51      0  7.63  1.12
# 3  Wonorejo  04/01/2019  731,185  1,127,891,639   4.41      0  7.84  1.38
# 4  Wonorejo  05/01/2019  731,185  1,127,891,639   3.69      0  9.72  1.51
#
#       O3   NO2  HC
# 0  28.37  4.96   0
# 1  24.21  0.00   0
# 2  14.35  0.00   0
# 3  21.03  0.00   0
# 4  25.00  0.00   0

# %%
Gabungan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4346 entries, 0 to 4345
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Lokasi   4346 non-null   object
#  1   Tanggal  4346 non-null   object
#  2   X        4346 non-null   object
#  3   Y        4346 non-null   object
#  4   PM10     4346 non-null   float64
#  5   PM2.5    4346 non-null   int64
#  6   SO2      4346 non-null   float64
#  7   CO       4346 non-null   float64
#  8   O3       4346 non-null   float64
#  9   NO2      4345 non-null   float64
#  10  HC       4346 non-null   int64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 373.6+ KB

# %%
Gabungan.drop(columns=['X','Y','SO2','CO','O3','NO2','HC'],inplace=True)
Gabungan.head()
# Out:
#      Lokasi     Tanggal   PM10  PM2.5
# 0  Wonorejo  01/01/2019  11.98      0
# 1  Wonorejo  02/01/2019  12.04      0
# 2  Wonorejo  03/01/2019   8.51      0
# 3  Wonorejo  04/01/2019   4.41      0
# 4  Wonorejo  05/01/2019   3.69      0

# %%
Gabungan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4346 entries, 0 to 4345
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Lokasi   4346 non-null   object
#  1   Tanggal  4346 non-null   object
#  2   PM10     4346 non-null   float64
#  3   PM2.5    4346 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 135.9+ KB

# %%
Gabungan['Tahun']=Gabungan['Tanggal'].str[-2:]
Gabungan.head()
# Out:
#      Lokasi     Tanggal   PM10  PM2.5 Tahun
# 0  Wonorejo  01/01/2019  11.98      0    19
# 1  Wonorejo  02/01/2019  12.04      0    19
# 2  Wonorejo  03/01/2019   8.51      0    19
# 3  Wonorejo  04/01/2019   4.41      0    19
# 4  Wonorejo  05/01/2019   3.69      0    19

# %%
Gabungan.tail()
# Out:
#          Lokasi    Tanggal   PM10  PM2.5 Tahun
# 4341  Kebonsari   8-Dec-24  37.58      0    24
# 4342  Kebonsari   9-Dec-24  38.57      0    24
# 4343  Kebonsari  10-Dec-24   0.00      0    24
# 4344  Kebonsari  11-Dec-24   0.00      0    24
# 4345  Kebonsari  12-Dec-24  15.37      0    24

# %%
Wonorejo = Gabungan[Gabungan['Lokasi'] == 'Wonorejo']
Kebonsari= Gabungan[Gabungan['Lokasi'] == 'Kebonsari']

# %%
Wonorejo['Lokasi'].unique()
# Out:
# array(['Wonorejo'], dtype=object)

# %%
Kebonsari['Lokasi'].unique()
# Out:
# array(['Kebonsari'], dtype=object)

# %%
baku_mutu = {
    "PM10": [(0, 50, 50), (50, 150, 100), (150, 350, 200), (350, 420, 300), (420, 500, 400)],
    "PM2_5": [(0, 15.5, 50), (15.5, 55.4, 100), (55.4, 150.4, 200), (150.4, 250.4, 300), (250.4, float('inf'), 400)]}

# %%
def calculate_ispu(value, pollutant):
    for lower_bound, upper_bound, ispu_value in baku_mutu[pollutant]:
        if lower_bound <= value < upper_bound:
            xx = value
            ia = ispu_value
            ib = ispu_value - 50  # ISPU untuk batas bawah
            xa = upper_bound
            xb = lower_bound

            ispu = (ia - ib) / (xa - xb) * (xx - xb) + ib
            return round(ispu, 1)
    return None

# %%
Sementara['ISPU PM10'] = Sementara['PM10'].apply(lambda x: calculate_ispu(x, 'PM10'))
Sementara['ISPU PM2.5'] = Sementara['PM2.5'].apply(lambda x: calculate_ispu(x, 'PM2_5'))
Sementara.head()
# Out:
#                               LOKASI PERUNTUKAN KAWASAN  PM2.5    PM10  Tahun  \
# 0     Kantor Kelurahan Bulak Banteng          Pemukiman   9.41   57.55   2023
# 1  Kantor Kelurahan Penjaringan Sari          Pemukiman  48.32  154.58   2023
# 2         Kantor Kecamatan Mulyorejo          Pemukiman  11.37   41.86   2023
# 3       Kantor Kelurahan Pucang Sewu          Pemukiman  32.95  169.23   2023
# 4         Kantor Kelurahan Wonokromo          Pemukiman  44.74  205.53   2023
#
#    ISPU PM10  ISPU PM2.5
# 0       53.8        30.4
# 1      151.1        91.1
# 2       41.9        36.7
# 3      154.8        71.9
# 4      163.9        86.6

# %%
Tandes['ISPU PM10'] = Tandes['PM10'].apply(lambda x: calculate_ispu(x, 'PM10'))
Tandes['ISPU PM2.5'] = Tandes['PM2.5'].apply(lambda x: calculate_ispu(x, 'PM2_5'))
Tandes.head()
# Out:
#       Tanggal  PM10  PM2.5 Tahun  ISPU PM10  ISPU PM2.5
# 0  01/01/2020    19     20    20       19.0        55.6
# 1  02/01/2020    12     13    20       12.0        41.9
# 2  03/01/2020    21     22    20       21.0        58.1
# 3  04/01/2020    13     14    20       13.0        45.2
# 4  05/01/2020    12     12    20       12.0        38.7

# %%
Wonorejo['ISPU PM10'] = Wonorejo['PM10'].apply(lambda x: calculate_ispu(x, 'PM10'))
Wonorejo['ISPU PM2.5'] = Wonorejo['PM2.5'].apply(lambda x: calculate_ispu(x, 'PM2_5'))
Wonorejo.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12032\2503511469.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Wonorejo['ISPU PM10'] = Wonorejo['PM10'].apply(lambda x: calculate_ispu(x, 'PM10'))
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12032\2503511469.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Wonorejo['ISPU PM2.5'] = Wonorejo['PM2.5'].apply(lambda x: calculate_ispu(x, 'PM2_5'))
#      Lokasi     Tanggal   PM10  PM2.5 Tahun  ISPU PM10  ISPU PM2.5
# ...

# %%
Kebonsari['ISPU PM10'] = Kebonsari['PM10'].apply(lambda x: calculate_ispu(x, 'PM10'))
Kebonsari['ISPU PM2.5'] = Kebonsari['PM2.5'].apply(lambda x: calculate_ispu(x, 'PM2_5'))
Kebonsari.head()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12032\2024423617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Kebonsari['ISPU PM10'] = Kebonsari['PM10'].apply(lambda x: calculate_ispu(x, 'PM10'))
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12032\2024423617.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Kebonsari['ISPU PM2.5'] = Kebonsari['PM2.5'].apply(lambda x: calculate_ispu(x, 'PM2_5'))
#          Lokasi     Tanggal   PM10  PM2.5 Tahun  ISPU PM10  ISPU PM2.5
# ...

# %% [markdown]
# # Visualisasi Tahun 2023

# %%
Sementara['Tahun'].unique()
# Out:
# array([2023, 2022, 2021, 2020], dtype=int64)

# %%
Sementara2023 = Sementara[Sementara['Tahun']==2023]
Sementara2023.head()
# Out:
#                               LOKASI PERUNTUKAN KAWASAN  PM2.5    PM10  Tahun  \
# 0     Kantor Kelurahan Bulak Banteng          Pemukiman   9.41   57.55   2023
# 1  Kantor Kelurahan Penjaringan Sari          Pemukiman  48.32  154.58   2023
# 2         Kantor Kecamatan Mulyorejo          Pemukiman  11.37   41.86   2023
# 3       Kantor Kelurahan Pucang Sewu          Pemukiman  32.95  169.23   2023
# 4         Kantor Kelurahan Wonokromo          Pemukiman  44.74  205.53   2023
#
#    ISPU PM10  ISPU PM2.5
# 0       53.8        30.4
# 1      151.1        91.1
# 2       41.9        36.7
# 3      154.8        71.9
# 4      163.9        86.6

# %%
Tandes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1806 entries, 0 to 1807
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Tanggal     1806 non-null   object
#  1   PM10        1806 non-null   int64
#  2   PM2.5       1806 non-null   int64
#  3   Tahun       1806 non-null   object
#  4   ISPU PM10   1806 non-null   float64
#  5   ISPU PM2.5  1806 non-null   float64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 98.8+ KB

# %%
Tandes2023PM10= Tandes[(Tandes['Tahun']=='23') & (Tandes['ISPU PM10'] != 0)]
Kebonsari2023PM10= Kebonsari[(Kebonsari['Tahun']=='23') & (Kebonsari['ISPU PM10'] != 0)]
Wonorejo2023PM10= Wonorejo[(Wonorejo['Tahun']=='23') & (Wonorejo['ISPU PM10'] != 0)]

# %%
plt.figure(figsize=(8,10))
sns.barplot(data=Sementara2023, y='LOKASI', x='ISPU PM10', hue='PERUNTUKAN KAWASAN', palette='Set2')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2023PM10['ISPU PM10'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2023PM10['ISPU PM10'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2023PM10['ISPU PM10'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2023PM10['ISPU PM10'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2023PM10['ISPU PM10'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2023PM10['ISPU PM10'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2023PM10['ISPU PM10'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2023PM10['ISPU PM10'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2023PM10['ISPU PM10'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %%
Tandes2023PM25= Tandes[(Tandes['Tahun']=='23') & (Tandes['ISPU PM2.5'] != 0)]
Kebonsari2023PM25= Kebonsari[(Kebonsari['Tahun']=='23') & (Kebonsari['ISPU PM2.5'] != 0)]
Wonorejo2023PM25= Wonorejo[(Wonorejo['Tahun']=='23') & (Wonorejo['ISPU PM2.5'] != 0)]

# %%
plt.figure(figsize=(8,10))
sns.barplot(data=Sementara2023, y='LOKASI', x='ISPU PM2.5', hue='PERUNTUKAN KAWASAN', palette='PiYG')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2023PM25['ISPU PM2.5'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2023PM25['ISPU PM2.5'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2023PM25['ISPU PM2.5'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2023PM25['ISPU PM2.5'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2023PM25['ISPU PM2.5'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2023PM25['ISPU PM2.5'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2023PM25['ISPU PM2.5'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2023PM25['ISPU PM2.5'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2023PM25['ISPU PM2.5'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %% [markdown]
# # Visualisasi Tahun 2022

# %%
Sementara2022 = Sementara[Sementara['Tahun']==2022]
Tandes2022PM10= Tandes[(Tandes['Tahun']=='22') & (Tandes['ISPU PM10'] != 0)]
Kebonsari2022PM10= Kebonsari[(Kebonsari['Tahun']=='22') & (Kebonsari['ISPU PM10'] != 0)]
Wonorejo2022PM10= Wonorejo[(Wonorejo['Tahun']=='22') & (Wonorejo['ISPU PM10'] != 0)]

# %%
plt.figure(figsize=(8,10))
sns.barplot(data=Sementara2022, y='LOKASI', x='ISPU PM10', hue='PERUNTUKAN KAWASAN', palette='Set3')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2022PM10['ISPU PM10'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2022PM10['ISPU PM10'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2022PM10['ISPU PM10'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2022PM10['ISPU PM10'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2022PM10['ISPU PM10'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2022PM10['ISPU PM10'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2022PM10['ISPU PM10'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2022PM10['ISPU PM10'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2022PM10['ISPU PM10'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %%
Sementara2022 = Sementara[Sementara['Tahun']==2022]
Tandes2022PM25= Tandes[(Tandes['Tahun']=='22') & (Tandes['ISPU PM2.5'] != 0)]
Kebonsari2022PM25= Kebonsari[(Kebonsari['Tahun']=='22') & (Kebonsari['ISPU PM2.5'] != 0)]
Wonorejo2022PM25= Wonorejo[(Wonorejo['Tahun']=='22') & (Wonorejo['ISPU PM2.5'] != 0)]

# %%
plt.figure(figsize=(8,10))
sns.barplot(data=Sementara2022, y='LOKASI', x='ISPU PM2.5', hue='PERUNTUKAN KAWASAN', palette='PiYG')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2022PM25['ISPU PM2.5'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2022PM25['ISPU PM2.5'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2022PM25['ISPU PM2.5'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2022PM25['ISPU PM2.5'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2022PM25['ISPU PM2.5'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2022PM25['ISPU PM2.5'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2022PM25['ISPU PM2.5'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2022PM25['ISPU PM2.5'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2022PM25['ISPU PM2.5'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %% [markdown]
# # Visualisasi Tahun 2021

# %%
Sementara2021 = Sementara[Sementara['Tahun']==2021]
Tandes2021PM10= Tandes[(Tandes['Tahun']=='21') & (Tandes['ISPU PM10'] != 0)]
Kebonsari2021PM10= Kebonsari[(Kebonsari['Tahun']=='21') & (Kebonsari['ISPU PM10'] != 0)]
Wonorejo2021PM10= Wonorejo[(Wonorejo['Tahun']=='21') & (Wonorejo['ISPU PM10'] != 0)]

# %%
plt.figure(figsize=(8,12))
sns.barplot(data=Sementara2021, y='LOKASI', x='ISPU PM10', hue='PERUNTUKAN KAWASAN', palette='Set3')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2021PM10['ISPU PM10'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2021PM10['ISPU PM10'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2021PM10['ISPU PM10'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2021PM10['ISPU PM10'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2021PM10['ISPU PM10'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2021PM10['ISPU PM10'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2021PM10['ISPU PM10'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2021PM10['ISPU PM10'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2021PM10['ISPU PM10'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %%
Sementara2021 = Sementara[Sementara['Tahun']==2021]
Tandes2021PM25= Tandes[(Tandes['Tahun']=='21') & (Tandes['ISPU PM2.5'] != 0)]
Kebonsari2021PM25= Kebonsari[(Kebonsari['Tahun']=='21') & (Kebonsari['ISPU PM2.5'] != 0)]
Wonorejo2021PM25= Wonorejo[(Wonorejo['Tahun']=='21') & (Wonorejo['ISPU PM2.5'] != 0)]

# %%
plt.figure(figsize=(8,12))
sns.barplot(data=Sementara2021, y='LOKASI', x='ISPU PM2.5', hue='PERUNTUKAN KAWASAN', palette='PiYG')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2021PM25['ISPU PM2.5'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2021PM25['ISPU PM2.5'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2021PM25['ISPU PM2.5'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2021PM25['ISPU PM2.5'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2021PM25['ISPU PM2.5'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2021PM25['ISPU PM2.5'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2021PM25['ISPU PM2.5'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2021PM25['ISPU PM2.5'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2021PM25['ISPU PM2.5'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %% [markdown]
# # Visualisasi Tahun 2020

# %%
Sementara2020 = Sementara[Sementara['Tahun']==2020]
Tandes2020PM10= Tandes[(Tandes['Tahun']=='20') & (Tandes['ISPU PM10'] != 0)]
Kebonsari2020PM10= Kebonsari[(Kebonsari['Tahun']=='20') & (Kebonsari['ISPU PM10'] != 0)]
Wonorejo2020PM10= Wonorejo[(Wonorejo['Tahun']=='20') & (Wonorejo['ISPU PM10'] != 0)]

# %%
plt.figure(figsize=(8,12))
sns.barplot(data=Sementara2020, y='LOKASI', x='ISPU PM10', hue='PERUNTUKAN KAWASAN', palette='Set2')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2020PM10['ISPU PM10'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2020PM10['ISPU PM10'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2020PM10['ISPU PM10'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2020PM10['ISPU PM10'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2020PM10['ISPU PM10'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2020PM10['ISPU PM10'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2020PM10['ISPU PM10'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2020PM10['ISPU PM10'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2020PM10['ISPU PM10'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()

# %%
Sementara2020 = Sementara[Sementara['Tahun']==2020]
Tandes2020PM25= Tandes[(Tandes['Tahun']=='20') & (Tandes['ISPU PM2.5'] != 0)]
Kebonsari2020PM25= Kebonsari[(Kebonsari['Tahun']=='20') & (Kebonsari['ISPU PM2.5'] != 0)]
Wonorejo2020PM25= Wonorejo[(Wonorejo['Tahun']=='20') & (Wonorejo['ISPU PM2.5'] != 0)]

# %%
plt.figure(figsize=(8,15))
sns.barplot(data=Sementara2020, y='LOKASI', x='ISPU PM2.5', hue='PERUNTUKAN KAWASAN', palette='PiYG')
plt.legend(title="Peruntukan Kawasan", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.axvline(x=Tandes2020PM25['ISPU PM2.5'].max(), color='black', linestyle='--', linewidth=1)
plt.axvline(x=Tandes2020PM25['ISPU PM2.5'].min(), color='black', linestyle=':', linewidth=1)
plt.axvline(x=Tandes2020PM25['ISPU PM2.5'].mean(), color='black', linewidth=1)
plt.axvline(x=Kebonsari2020PM25['ISPU PM2.5'].max(), color='red', linestyle='--', linewidth=1)
plt.axvline(x=Kebonsari2020PM25['ISPU PM2.5'].min(), color='red', linestyle=':', linewidth=1)
plt.axvline(x=Kebonsari2020PM25['ISPU PM2.5'].mean(), color='red', linewidth=1)
plt.axvline(x=Wonorejo2020PM25['ISPU PM2.5'].max(), color='blue', linestyle='--', linewidth=1)
plt.axvline(x=Wonorejo2020PM25['ISPU PM2.5'].min(), color='blue', linestyle=':', linewidth=1)
plt.axvline(x=Wonorejo2020PM25['ISPU PM2.5'].mean(), color='blue', linewidth=1)
plt.axvspan(100,200, color='black', alpha=0.3, label='Tidak Layak Hirup')
plt.show()
